# %% [markdown]
# # A2: Text Adventure Game
#
# ## intro
#
# This game is inspired by the movie Black Panther 2 that has been released few month ago.
# You play the role of the warrior who has been chosen, and your mission is to find the princess' location by traveling through perilous environment, slaying terrible beasts, and solving puzzles. Your goal is to save the princess and return her to the kingdom, preventing the kingdom's upcoming ruin.
# You will run into a number of challenges and enigma along the route that will put your abilities to the test. In order to help you in your search, you will have the chance to arm yourself with strong weapons and equipment.
#
#
# ## stage description
#
# The game is dived into 4 mains stages:
# * Gather informations about the princess' location
# * Choose the right equipment for the mission
# * Investigate Velia and find the enemy's hideout
# * Navigate through the Underwater Kingdom and save the princess
#
#
# ## Bugs
#
# I was able to fix most of the bugs. I didn't find any more bugs.
#
#
# ## Movie Citation
#
# Coogler, R. (2022). Black Panther 2. Walt Disney Studios Motion Pictures.

# %%
#Author: Kevin Kabore
#Text adventure game based on Black Panther 2

# import package for my game
import time  # time package
import random  # random package


# defining the win function that will be use when the player win the game
def win():
    print("""



██╗   ██╗ ██████╗ ██╗   ██╗    ██╗    ██╗ ██████╗ ███╗   ██╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║    ██║██╔═══██╗████╗  ██║
 ╚████╔╝ ██║   ██║██║   ██║    ██║ █╗ ██║██║   ██║██╔██╗ ██║
  ╚██╔╝  ██║   ██║██║   ██║    ██║███╗██║██║   ██║██║╚██╗██║
   ██║   ╚██████╔╝╚██████╔╝    ╚███╔███╔╝╚██████╔╝██║ ╚████║
   ╚═╝    ╚═════╝  ╚═════╝      ╚══╝╚══╝  ╚═════╝ ╚═╝  ╚═══╝    

    """)


# defining the loose function that I will use when the player loose the game
def fail():
    print("""

██╗   ██╗ ██████╗ ██╗   ██╗    ██╗      ██████╗ ███████╗████████╗
╚██╗ ██╔╝██╔═══██╗██║   ██║    ██║     ██╔═══██╗██╔════╝╚══██╔══╝
 ╚████╔╝ ██║   ██║██║   ██║    ██║     ██║   ██║███████╗   ██║   
  ╚██╔╝  ██║   ██║██║   ██║    ██║     ██║   ██║╚════██║   ██║   
   ██║   ╚██████╔╝╚██████╔╝    ███████╗╚██████╔╝███████║   ██║   
   ╚═╝    ╚═════╝  ╚═════╝     ╚══════╝ ╚═════╝ ╚══════╝   ╚═╝   

    """)


# wrong input function when user inser a wrong input
def wrong_input():
    print("\n We didn't recognize your input. Please follow the instruction")
    input("<Enter to try again>")


# restart function when player need to restart the stage
def restart():
    input('Enter to try again')


#Introduction function to introduce the goal of the game. This is not a stage
def intro():
    # yeslist and nolist for user choice. I want the user to have a variety of input
    yes_list = ['Yes', 'Y', 'Yeah', 'Yes I want', ]
    no_list = ['No', 'N', "No I don't"]
    #user input name
    warrior_name = input('Warrior! What is your name?\nEnter your name here --> ').capitalize()
    print('-' * 80)  # seperate text and have a better display
    print(f" {warrior_name}, You have been requested by the queen")
    print("As you walk down the long hallway, you wonder what is happening. You notice that the kingdom is agitated. ")
    print("You feel worried, but you decide to stay calm")
    time.sleep(2) #put a time between the display of text
    print('-' * 80)
    print('Entering into the throne room...')
    print('-' * 80)
    time.sleep(2)
    print("You look around and see only the queen's spokesman and the queen.")
    print("You take two steps, three steps and he starts to speak:")
    time.sleep(1)
    print('-' * 80)
    print(
        f'"Greetings, Warrior {warrior_name}. I am here to inform you that the kingdom is in dire need of your services."')
    print('"Our beloved princess Shuri has been kidnapped by a group of ruthless bandits."')
    print('"As the kingdom\'s most skilled and courageous warrior,"')
    print('"The princess has requested your help in saving her."')
    print('-' * 80)
    time.sleep(1)
    #while loop to control user choice and mistake.If input wrong or 'no' user can come back here
    while True:
        mission = input(
            '"Would you like accept the mission ? (Y/N)" ').capitalize()  # player decide if he want to start the game
        #conditional statements direct the player to different outcomes based on their choices
        if mission in yes_list:#choice1
            print('"it is your duty to rescue the princess and bring her back to the castle."')
            print('"The journey ahead will be perilous and filled with danger,"')
            print('"but I have faith that you are the only one who can complete this mission."')
            stage1()
            break

        elif mission in no_list:#choice 2
            print("As a proud Wakanda warrior, it is a dishonor to decline such a crucial mission.")
            print("We must ask that you depart the kingdom.")
            input("Enter to restart")
            continue

        else:#if user imput not regocnize
            wrong_input()
            continue


#The first stage of the game after accepting the mission is gathering information about the kidnappers and their location
def stage1():
    print('-' * 80)  # text separator
    print(f"Your initial task will be to gather information on the unknown group and their whereabouts.")
    print("Where do you want to start ?")
    print('-' * 80)
    # user first choice in stage1
    choice1 = input("""
    1. Investigate by questioning the guard who was with the princess when she was kidnapped
    2. Speak with the queen for further information and guidance
    (Enter (1) or (2))   """)
    #there are two different ways to gather the information on the princess's location
    if choice1 == '1':
        print('-' * 80)
        print("As you make your way to the guard's home, you arrive at his residence")
        print("What information do you hope to gain from him about the princess's kidnapping?")
        while True: #use the while loop to control user incorrect input
            #this choice bring to the guard house
            choice1_1 = input("""
            1. Can you tell me what happened during the attack on the princess?
            2. Do you have any information on the location of the kidnappers' hideout?
            (Enter (1) or (2)  """)
            print('-' * 80)
            if choice1_1 == '1':
                print('-' * 80)
                print('"We were ambushed on our way back to the kingdom"')
                print('"The attackers came from the water, they looked human but their skin was blue."')
                print('"They were outfitted with Vibranium equipments and weapons."')
                print('-' * 80)
                input('<Press Enter for more information on the kidnappers location>')
                print('-' * 80)
                print('"I remember a story from my youth in the small town of Velia"')
                print('"You might find more information there"')
                equip_room()
                break #breaking the loop

            elif choice1_1 == '2':
                print('-' * 40)
                print('"I\'m sorry, I do not know the exact location of their hideout."')
                print('"But I remember a story from my youth in the small town of Velia"')
                print("there were rumors of blue-skinned humans being")
                print('"You might find more information there"')
                equip_room()
                break #breaking the loop

            else:
                wrong_input()
                continue #loop continue if user
    #choice to talk to the princess
    elif choice1 == '2':
        print('-' * 80)
        print(f'"Please bring my daughter back to me! I have heard that this unknown group is not human"')
        print('"They possess incredible strength and are able to swim and breath underwater"')
        print('"They are also equipped with Vibranium equipment."')
        print('"it remind me that legend in this small village called Velia"')
        equip_room()

    else:
        wrong_input()
        stage1()


# this is second stage of stage where the warrior go in the equipement room to prepare himself
# for the battle

#Second stage player have to choose the equipements to save the princess
def equip_room():
    time.sleep(1.5)
    print('-' * 80)
    print('Entering the equipment room...')
    print('-' * 80)
    time.sleep(1.5)
    print("""
                    Welcome to the Wakanda warrior equipment room! 
        You have been assigned to arm yourself with the necessary equipment 
                    to defeat your opponents and save the princess. 
                    Based on the information you have acquired.
                what type of equipment do you desire to utilize?
""")
    print('-' * 80)
    time.sleep(1)
    print("There is the sets available  for you:\n")
    time.sleep(0.75)
    set_1 = ['Vibranium Sword', 'Underwater motorcycle', 'suit made for underwater fight']
    time.sleep(0.75)
    set_2 = ['bike', 'teddy bear', 'flash light']
    time.sleep(0.75)
    set_3 = ['wooden sword', 'sun glasses', 'fishing rod', 'football', 'gloves']
    time.sleep(0.75)
    inventory = [] #create empty list that I will use to display user inventory
    inventory1 = []#each inventory is used for different outcome
    inventory2 = []
    print(f"1. {set_1}")
    print(f"2. {set_2}")
    print(f"3. {set_3}")
    print('-' * 80)
    while True:
            print("'Which set do you want?(Based on the information you gather earlier)'")
            equip_choice = input('Enter number (1), (2) or (3): ')
            #set 1
            if equip_choice == '1':
                inventory.append(set_1)
                print('This is your inventory: ')
                time.sleep(0.5)
                print(inventory)
                time.sleep(0.5)
                print('You are now ready to travel to Veila.')
                input('<press enter to continue>')
                time.sleep(2)
                velia()
                break
            #set 2
            elif equip_choice == '2':
                print('-' * 80)
                inventory1.append(set_2)
                print('This is your inventory: ')
                time.sleep(0.5)
                print(inventory1)
                time.sleep(0.5)
                print('On your way to Veila riding your beautiful bike you have been attacked by some bandit on the road.')
                print('You tried to defend yourself with your teddy bear...')
                print('but they laughed at you and killed you.')
                print('What a tragic end for a proud Wakanda warrior.')
                print('-' * 80)
                time.sleep(1)
                fail()
                time.sleep(1)
                restart()
                time.sleep(1)
                continue

            #set 3
            elif equip_choice == '3':
                inventory2.append(set_3)
                print('This is your inventory: ')
                time.sleep(0.5)
                print(inventory2)
                time.sleep(0.5)
                input('<press enter to countinue>')
                time.sleep(1)
                print('-' * 80)
                print('Did you thought you were going on vacation ?')
                print('It\'s an important mission we are not sending you at the beach')
                print('Return to the room and select a suitable set for the mission.')
                time.sleep(0.5)
                restart()
                time.sleep(0.5)
                continue
        
            else: 
                wrong_input()
                continue
        


# stage where player arrive to Velia
def velia():
    yes_list1 = ['Yes', 'Y', 'Yeah', 'Yes I want', 'Yeah']  # yes list for user input 
    no_list1 = ['No', 'N', "No I don't", 'Nah', 'None'] # no list for user input
    velia_inventory = ['Vibranium Sword', 'Underwater motorcycle', 'Suit for underwater fight'] #player inventory
    print('-' * 80)
    print('Welcome to the village of Velia')
    print('You heard about his lady that is the elder of the village')
    print('-' * 80)
    print('1. Go talk the the old lady')
    print('2. Exit the village')
    velia_choice = input('Choose 1 or 2: ')
    if velia_choice == '1':
        print('-' * 80)
        print("You arrive at the elder place you explained her the story of the kidnaping")
        print("She start to tell you about the God called Takoli")
        print("It's a God they worship. He has a kingdom underwater")
        print("There is a cave where they are bringing there offering to this God ")
        input('<Enter to go to the cave>')
        print('-' * 80)
        print('You arrive to the cave...')
        print('What do you want to do ?')
        while True: #Building a nested while loop that will play this loop until until the player inser the correct input
            print("""
                 1. Investigate around the altar 
                 2. You saw something moving but it's dark. Go and check what it is.

              """)
            choice2_2 = input('Choose 1 or 2') #first choice in the nested while loop
            if choice2_2 == '1': #conditinal statement thaht control user input
                print("When you arrive close to the altar you noticed that... ")
                print("the offering baskets are empty")
                input("<Press enter to continue the investigation>")
                time.sleep(1)
                print("You start to see some footprints")
                print("Do you want to follow the footprints ?")
                while True: # while loop in the nested while loop
                    choice2_21 = input('Yes or No (Y/N)').capitalize()
                    if choice2_21 in yes_list1:
                        print("The footprints led you to a lake deep in the cave")
                        print("Look like someone dived here")
                        input('<Press enter to dive>')
                        underwater_world() #bring the user to the last stage of the game
                        break #breaking the while  loop if the user choose this path
                    elif choice2_21 in no_list1:
                        print("You continue investigating but do not find any further relevant information")
                        print("You come back but the footprint disapears")
                        print("You lost track of the enemies")
                        fail()
                        restart()
                        continue #restart the loop if the user choose  the path and fail the game
                    
                    
                    
                    else:
                        wrong_input()
                        continue #restart the loop if the user got a wrong input
                break #breaking the nested loop
            elif choice2_2 == '2':
                print("You were attacked from behind and did not have time to defend yourself")
                print("You died!")
                fail()
                restart()
                continue #restart the nested loop if user choose this path and fail the game
                
            else:
                wrong_input()
                restart()
                continue #restart the nested loop if the user got a wrong input
    #if the user choose this path he is loosing the game and can restart the stage
    elif velia_choice == '2':
        print('You are leaving the village..')
        print('What a shame warrior you are running away from your duty')
        print("The princess wasn't that important for you!")
        fail()
        restart()
        velia()
    else:
        wrong_input()
        velia()#if the player put a wrong input, player restart the stage


# last stage of my game

def underwater_world():
    #using list to store user inventory
    warrior_inventory = ["Vibranium Sword", "Underwater motorcycle", "suit made for underwater fight"]
    print('-' * 80)
    print("""
                            Welcome to the underwater world! 
            It looks like you are on a good path to rescuing the princess.
        You are entering the last stage of your mission, be extremely cautious.
        Pay attention to each decision you make, as it could cost you your life.     
                          """)
    print('-' * 80)
    print("There is your inventory:")
    #for loop print each object of the user inventory
    for item in warrior_inventory: 
        print(item)
    print('-' * 80)
    while True:
        print('Choose an item to navigate quickly through the water')
        #dynamic printing. the user need to select the right item to progress the game
        print(f"""
                         1. {warrior_inventory[0]}
                         2. {warrior_inventory[1]}
                         3. {warrior_inventory[2]}
                         """)  
        un_choice = input("choose 1,2 or 3")
        if un_choice == '2':
            print('-' * 80)
            print(f"You choose {warrior_inventory[1]}. You will be able to navigate through the water")
            choose_path()
            break

        elif un_choice == '1' or un_choice == '3':
            print('-' * 80)
            print('You drawn because of the high pressure!')
            time.sleep(0.5)
            fail()
            time.sleep(0.5)
            restart()
            continue

        else:
            wrong_input()
            time.sleep(0.5)
            continue


#last stage of the game
def choose_path():

    yes_list2 = ['Yes', 'Y', 'Yeah', 'Yes I want', 'Yeah']  # List for user input
    no_list2 = ['No', 'N', "No I don't", 'Nah', 'None']

    warrior_inventory1 = ['Vibranium Sword', 'Underwater motorcycle', 'Suit for underwater fight']
    print('-' * 80)
    print("You came across 2 paths")
    print("Which one do you want to take ?")
    print("""
                1. Path 1
                2. Path 2
        """)
    path_choice = input('Input (1) or (2)')
    print('-' * 80)
    if path_choice == '1':
        print('While driving underwater in search of the location where the princess is being held, you come across a monster')
        input("<Press enter to fight him>")
        time.sleep(1.5)
        print("You drew your Vibranium sword in slice the monster in half")
        #depending on the user's input, there are two different endings
        while True: #nested while loop to control user wrong input
            choice_path = input('Something felt out of his pocket. Do you want to pick it up ? Enter(Y/N)').capitalize()
            #path 1 with code
            if choice_path in yes_list2:
                print("There is a code written on a paper: '120'")
                print("this code must be  very important")
                input("<Enter to continue>")
                print('-' * 80)
                time.sleep(1)
                print(""""
                    You keep making your way through the underworld until you reach the princess's location.
                    However, you have to guess a code to open the prison where she is imprisoned. 
                    The number seems to be three digits.
                """)
                number1 = 120 #code user need to guess 
                chance1 = 2 #2 chances to insert the  right code 
                while chance1 > 0:
                    print('-' * 80)
                   
                    guess1 = input('Guess the right number to unlock the door')
                        
                    try:
                        guess1 = int(guess1)
                        
                    except:
                        input(prompt = 'Please insert a number! <Enter to try again>')
                        
                        
                    if guess1 == number1:
                        print('You have unlock the door and save the princess')
                        time.sleep(2)
                        win()
                        break

                    elif guess1 != number1:
                        chance1 -= 1
                        print(f"Wrong number! Try again you have {chance1} chance left")
                        if chance1 == 0:
                            time.sleep(1)
                            print("You ran out of time the guard came and killed you")
                            time.sleep(1)
                            fail()
                            time.sleep(0.5)
                            restart()
                            #player can't guess the code he have to start at the begining of the stage
                            choose_path() 
                            
                        

                    else:
                        print("Incorrect input")
                        continue
                break #breaking the nested while loop
            #path 2 without piking up the code    
            elif choice_path in no_list2:
                print('-' * 80)
                print("""
    You keep navigating through the underworld and you arrive arrive at the princess location.
    But seems like she is inside a prison with a code you must guess a number to unlock the prison.
    Look like it's a number between 0 and 9       
                """)
                number = random.randint(0, 9) #the code will generate a random number between 0 and 9
                chance = 5 #5 chance to guess a number between 0 and  9
                while chance > 0:
                    guess = int(input('Enter a number betweent 0 and 9 to unlock the door'))
                    #if the user's input match the random number he win the game.
                    if guess == number:
                        print('-' * 80)
                        print('You have unlock the door and save the princess')
                        time.sleep(2)
                        win()
                        break
                    #if not matching the the code he can try until he ran out of chance
                    elif guess != number:
                        chance -= 1
                        print(f"Wrong number! Try again you have {chance} chance left")
                        if chance == 0:
                            print('-' * 80)
                            time.sleep(1)
                            print("You ran out of time a guard came and killed you")
                            time.sleep(1)
                            fail()
                            time.sleep(0.5)
                            restart()
                            choose_path() #start the stage if player loose

                        elif guess > 9 or guess < 1:
                            print("\n Please choose a number between 0 and 9")
                            

                    else:
                        print("Incorrect input")
                        continue
                break #breaking the nested while loop 
            else:
                wrong_input()
                continue #nested while loop keep running
            
            
    elif path_choice == '2':
        print('-' * 80)
        print("""
    While you were sailing underwater you were swept away by a submarine vortex and drowned!
          """)
        time.sleep(2)
        fail()
        restart()
        time.sleep(1)
        choose_path()
        
    else:
        wrong_input()
        choose_path()

#start of my code
print('-' * 80)
print(""" 

  ____  _            _      _____            _   _               
 |  _ \| |          | |    |  __ \          | | | |              
 | |_) | | __ _  ___| | __ | |__) |_ _ _ __ | |_| |__   ___ _ __ 
 |  _ <| |/ _` |/ __| |/ / |  ___/ _` | '_ \| __| '_ \ / _ \ '__|
 | |_) | | (_| | (__|   <  | |  | (_| | | | | |_| | | |  __/ |   
 |____/|_|\__,_|\___|_|\_\ |_|   \__,_|_| |_|\__|_| |_|\___|_|   



            """)
print('-' * 80)
#calling intro to start the game
intro()
